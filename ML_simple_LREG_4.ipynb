# %% [markdown]
# <a href="https://colab.research.google.com/github/mehdiiiii786/MEHDI-HADRI-G4-S6-Ass-1/blob/main/ML_simple_LREG_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/prices.csv')
df
# Out:
#                       date symbol        open       close         low  \
# 0      2016-01-05 00:00:00   WLTW  123.430000  125.839996  122.309998
# 1      2016-01-06 00:00:00   WLTW  125.239998  119.980003  119.940002
# 2      2016-01-07 00:00:00   WLTW  116.379997  114.949997  114.930000
# 3      2016-01-08 00:00:00   WLTW  115.480003  116.620003  113.500000
# 4      2016-01-11 00:00:00   WLTW  117.010002  114.970001  114.089996
# ...                    ...    ...         ...         ...         ...
# 35527           2010-04-22    FOX   18.320005   18.519995   18.040005
# 35528           2010-04-22   FOXA   15.919994   16.060000   15.629999
# 35529           2010-04-22    FRT   75.370003   77.830002   75.150002
# 35530           2010-04-22   FSLR  129.500000  133.940002  129.360001
# 35531           2010-04-22    FTI   66.040001   68.000000         NaN
#
#              high      volume
# 0      126.250000   2163600.0
# 1      125.540001   2386400.0
# 2      119.739998   2489500.0
# ...

# %%
df1= df.dropna()

# %%
df1
# Out:
#                       date symbol        open       close         low  \
# 0      2016-01-05 00:00:00   WLTW  123.430000  125.839996  122.309998
# 1      2016-01-06 00:00:00   WLTW  125.239998  119.980003  119.940002
# 2      2016-01-07 00:00:00   WLTW  116.379997  114.949997  114.930000
# 3      2016-01-08 00:00:00   WLTW  115.480003  116.620003  113.500000
# 4      2016-01-11 00:00:00   WLTW  117.010002  114.970001  114.089996
# ...                    ...    ...         ...         ...         ...
# 35526           2010-04-22    FMC   63.540001   64.540001   63.450001
# 35527           2010-04-22    FOX   18.320005   18.519995   18.040005
# 35528           2010-04-22   FOXA   15.919994   16.060000   15.629999
# 35529           2010-04-22    FRT   75.370003   77.830002   75.150002
# 35530           2010-04-22   FSLR  129.500000  133.940002  129.360001
#
#              high      volume
# 0      126.250000   2163600.0
# 1      125.540001   2386400.0
# 2      119.739998   2489500.0
# ...

# %%
first_symbol = df['symbol'].iloc[0]
newdf = df[df['symbol'] == first_symbol]

# %%
newdf
# Out:
#                     date symbol        open       close         low  \
# 0    2016-01-05 00:00:00   WLTW  123.430000  125.839996  122.309998
# 1    2016-01-06 00:00:00   WLTW  125.239998  119.980003  119.940002
# 2    2016-01-07 00:00:00   WLTW  116.379997  114.949997  114.930000
# 3    2016-01-08 00:00:00   WLTW  115.480003  116.620003  113.500000
# 4    2016-01-11 00:00:00   WLTW  117.010002  114.970001  114.089996
# ..                   ...    ...         ...         ...         ...
# 246  2016-12-23 00:00:00   WLTW  123.089996  124.489998  122.709999
# 247  2016-12-27 00:00:00   WLTW  124.570000  124.279999  124.010002
# 248  2016-12-28 00:00:00   WLTW  124.300003  122.379997  121.900002
# 249  2016-12-29 00:00:00   WLTW  122.449997  122.169998  121.599998
# 250  2016-12-30 00:00:00   WLTW  122.589996  122.279999  121.389999
#
#            high     volume
# 0    126.250000  2163600.0
# 1    125.540001  2386400.0
# 2    119.739998  2489500.0
# 3    117.440002  2006300.0
# ...

# %%
plt.scatter(newdf['open'],newdf['close'])

plt.ylabel('open price')
plt.xlabel('close price')
plt.show()

# %%
x= newdf.open.to_numpy()
y= newdf.close.to_numpy()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train.reshape(-1,1),y_train)
print('the coefficient is : ',  regressor.coef_[0])
print('the intercept is : ', regressor.intercept_)
# Out:
# the coefficient is :  0.9568947367332384
# the intercept is :  5.2799408460202955

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train, regressor.coef_[0] * x_train + regressor.intercept_)

# %%
y_test_ = regressor.predict(x_test.reshape(-1,1))

# %%
data = { 'actual closing price': y_test, 'predicted closing price' : y_test_}
pd.DataFrame(data)
# Out:
#     actual closing price  predicted closing price
# 0             121.470001               122.509117
# 1             121.000000               118.518860
# 2             123.410004               123.360753
# 3             122.720001               122.116786
# 4             120.589996               119.695845
# 5             122.209999               121.839287
# 6             122.750000               121.887134
# 7             126.559998               125.264971
# 8             115.470001               114.452058
# 9             123.839996               123.810495
# 10            121.480003               121.418258
# 11            119.940002               121.475669
# 12            129.580002               128.460996
# 13            132.770004               128.882032
# 14            127.330002               126.365402
# 15            122.309998               121.159892
# 16            126.449997               126.891689
# 17            127.290001               127.121350
# ...
